# %% [markdown]
# ***@Author: Ranjith G C***
# <br>
# ***@Date: 2021-08-21***
# <br>
# ***@Last Modified by: Ranjith G C***
# <br>
# ***@Last Modified time: 2021-08-21***
# <br>
# ***@Title : Program Aim to work with twitter sentimental analysis.***
# <br>

# %%
import tweepy
import matplotlib.pyplot as plt
from  textblob import TextBlob 
import csv
import time
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# all 4 authentication keys to access twitter API
# to connect as OAth handler or jump serever / revers proxy server
consumer_key=os.getenv('CONSUMER_KEY')
consumer_secrete=os.getenv('CONSUMER_SECRETE')
access_token=os.getenv('ACCESS_TOKEN')
access_secrete=os.getenv('ACCESS_SECRETE')

# %%
# connected to jump server of twitter
auth = tweepy.OAuthHandler(consumer_key,consumer_secrete)

# %%
# now we can connect from jump server to web server of twitter
auth.set_access_token(access_token,access_secrete)

# %%
# now we can connect to API storge server of twitter
api_connect=tweepy.API(auth)

# %%
# now you can search any topic on twitter
tweet_data=api_connect.search('Taliban')

# %%
pos='positive'
neg='negative'
p_count=0
n_count=0

opinion = ["pos","neg","p_count","n_count"]

with open('data.csv', 'w') as csv_file:
      csv_writer = csv.DictWriter(csv_file, fieldnames=opinion)
      csv_writer.writeheader()

while True:
# printing line by line
   with open('data.csv', 'a') as csv_file:
      for tweet in tweet_data:
         print(tweet.text)
         analysis=TextBlob(tweet.text) # here it will apply NLP\
         print(analysis.sentiment)
         # now checking polarity only
         if analysis.sentiment.polarity > 0:
            print("positive")
            p_count = p_count + 1
         elif analysis.sentiment[0]<0:
            print("Negative")
            n_count = n_count + 1
         else :
            print("Neutral")
         csv_writer = csv.DictWriter(csv_file, fieldnames=opinion)
         info = {
                  "pos": pos,
                  "neg": neg,
                  "p_count":p_count,
                  "n_count":n_count
                  }
         csv_writer.writerow(info)
         time.sleep(1) 
         print(p_count,n_count)
# Out:
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 0 1
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 0 1
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 0 1
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 0 1
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 0 1
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 0 1
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 0 2
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 0 2
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 0 2
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 0 3
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 1 3
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 1 3
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 2 3
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 2 4
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 4
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 2 5
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 5
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 5
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 5
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 5
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 5
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 2 6
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 6
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 6
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 2 7
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 3 7
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 3 7
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 4 7
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 4 8
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 4 8
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 4 9
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 4 9
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 4 9
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 4 9
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 4 9
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 4 9
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 4 10
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 4 10
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 4 10
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 4 11
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 5 11
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 5 11
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 6 11
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 6 12
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 6 12
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 6 13
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 6 13
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 6 13
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 6 13
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 6 13
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 6 13
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 6 14
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 6 14
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 6 14
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 6 15
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 7 15
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 7 15
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 8 15
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 8 16
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 16
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 8 17
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 17
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 17
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 17
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 17
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 17
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 8 18
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 18
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 18
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 8 19
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 9 19
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 9 19
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 10 19
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 10 20
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 10 20
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 10 21
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 10 21
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 10 21
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 10 21
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 10 21
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 10 21
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 10 22
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 10 22
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 10 22
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 10 23
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 11 23
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 11 23
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 12 23
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 12 24
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 12 24
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 12 25
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 12 25
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 12 25
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 12 25
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 12 25
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 12 25
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 12 26
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 12 26
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 12 26
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 12 27
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 13 27
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 13 27
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 14 27
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 14 28
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 28
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 14 29
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 29
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 29
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 29
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 29
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 29
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 14 30
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 30
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 30
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 14 31
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 15 31
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 15 31
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 16 31
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 16 32
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 16 32
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 16 33
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 16 33
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 16 33
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 16 33
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 16 33
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 16 33
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 16 34
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 16 34
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 16 34
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 16 35
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 17 35
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 17 35
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 18 35
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 18 36
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 18 36
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 18 37
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 18 37
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 18 37
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 18 37
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 18 37
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 18 37
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 18 38
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 18 38
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 18 38
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 18 39
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 19 39
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 19 39
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 20 39
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 20 40
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 40
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 20 41
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 41
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 41
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 41
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 41
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 41
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 20 42
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 42
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 42
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 20 43
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 21 43
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 21 43
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 22 43
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 22 44
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 22 44
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 22 45
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 22 45
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 22 45
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 22 45
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 22 45
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 22 45
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 22 46
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 22 46
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 22 46
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 22 47
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 23 47
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 23 47
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 24 47
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 24 48
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 24 48
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 24 49
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 24 49
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 24 49
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 24 49
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 24 49
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 24 49
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 24 50
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 24 50
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 24 50
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 24 51
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 25 51
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 25 51
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 26 51
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 26 52
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 52
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 26 53
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 53
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 53
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 53
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 53
# RT @NickKnudsenUS: “[Pompeo] signed a surrender agreement with the Taliban. This collapse goes back to the capitulation agreement of 2020.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 53
# RT @dna: #SalmanKhan's Afghan heroine #WarinaHussain shares her horror of #Taliban, says 'family was forced to flee #Afghanistan'
#
# #afghani…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Negative
# 26 54
# Türkiye Taliban ülkesi olmasın diyen generalleri hapse attılar! https://t.co/vyfTuquvLV #gazetesozcu @gazetesozcu aracılığıyla
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 54
# RT @rdzaminhat: aku taknak hidup bawah Taliban, never. aku rasa kau pun taknak, tapi kau poyo dan bangang. cuti kau berangan pergi europe j…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 54
# RT @JasonKander: When I try and fail to help Afghans get out or when I read stories about kids killed as families try to escape, I seek the…
# Sentiment(polarity=-0.35, subjectivity=0.14999999999999997)
# Negative
# 26 55
# RT @JoyceWhiteVance: Stark refutation of Pompeo’s claim he kept Afghanistan stable: “None of this is true. Like many other Republicans who…
# Sentiment(polarity=0.13124999999999998, subjectivity=0.53125)
# positive
# 27 55
# RT @HSajwanization: Aryana Sayeed, #Afghanistan’s pop singer who just fled #Kabul.  In 2015, when she sang at a stadium, breaking 3 taboos:…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 27 55
# RT @alfonslopeztena: Men from Afghanistan's secret gay community say they are living through a nightmare and fear that the Taliban will exe…
# Sentiment(polarity=0.008333333333333331, subjectivity=0.6416666666666666)
# positive
# 28 55
# @hank_brandtjen @BNeidhardt With 50,000 Americans being killed by the taliban $80 billion in weapons given to the t… https://t.co/MeUwj47NYf
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Negative
# 28 56
# RT @TamilTheHindu: தலிபான்களிடம் சிக்கிய இந்தியர்கள்: 168 பேர் பத்திரமாக மீட்பு: இந்தியா வந்தனர் https://t.co/jncwqAm2D6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 28 56
# RT @BalkyHillMama: Didn't Biden say that the Taliban were helping Americans escape Afghanistan? How could he be wrong? 🤦‍♀️🤡
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Negative
# 28 57
# RT @pakistan_untold: Taliban's victory is from Allah. But food for dying Afghans will come from Kafir govts &amp; NGOs.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 28 57
# RT @GurudathShettyK: Dr.@Swamy39 ji questions the Govt.'s silence on China -
#
# " I hope that our government is not playing up Taliban to ob…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 28 57
# @malaysiakini Bodoh budak ni. UK pun nak kerjasama dengan Taliban.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 28 57
# RT @AlinejadMasih: These two women were turned away from their work by Taliban. “The Taliban haven’t changed in 20 years but we are not the…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-5bbeefa2504e> in <module>
#      34                   }
#      35          csv_writer.writerow(info)
# ---> 36          time.sleep(1)
#      37          print(p_count,n_count)
#
# KeyboardInterrupt:
