# %%
import tweepy
import matplotlib.pyplot as plt
from  textblob import TextBlob 
import csv
import time
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# all 4 authentication keys to access twitter API
# to connect as OAth handler or jump serever / revers proxy server
consumer_key=os.getenv('CONSUMER_KEY')
consumer_secrete=os.getenv('CONSUMER_SECRETE')
access_token=os.getenv('ACCESS_TOKEN')
access_secrete=os.getenv('ACCESS_SECRETE')

# %%
# connected to jump server of twitter
auth = tweepy.OAuthHandler(consumer_key,consumer_secrete)

# %%
# now we can connect from jump server to web server of twitter
auth.set_access_token(access_token,access_secrete)

# %%
# now we can connect to API storge server of twitter
api_connect=tweepy.API(auth)

# %%
# now you can search any topic on twitter
tweet_data=api_connect.search('Taliban')

# %%
pos=0
neg=0

opinion = ["pos","neg"]

with open('data.csv', 'w') as csv_file:
      csv_writer = csv.DictWriter(csv_file, fieldnames=opinion)
      csv_writer.writeheader()

while True:
# printing line by line
   with open('data.csv', 'a') as csv_file:
      for tweet in tweet_data:
         print(tweet.text)
         analysis=TextBlob(tweet.text) # here it will apply NLP\
         print(analysis.sentiment)
         # now checking polarity only
         if analysis.sentiment.polarity > 0:
            print("positive")
            pos=pos+1
         elif analysis.sentiment[0]<0:
            print("Negative")
            neg =neg+1
         else :
            print("Neutral")
         csv_writer = csv.DictWriter(csv_file, fieldnames=opinion)
         info = {
                  "pos": pos,
                  "neg": neg
                  }
         csv_writer.writerow(info)
         print(pos, neg)
         time.sleep(1)
# Out:
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 1 0
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 1 0
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 1 1
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 1 1
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 1 2
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 2 2
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 2
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 2 3
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 2 3
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 3 3
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 4 3
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 4 3
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 5 3
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 5 3
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 6 3
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 7 3
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 7 3
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 7 4
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 7 4
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 7 5
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 8 5
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 5
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 8 6
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 8 6
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 9 6
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 10 6
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 10 6
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 11 6
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 11 6
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 12 6
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 13 6
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 13 6
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 13 7
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 13 7
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 13 8
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 14 8
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 8
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 14 9
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 14 9
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 15 9
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 16 9
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 16 9
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 17 9
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 17 9
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 18 9
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 19 9
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 19 9
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 19 10
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 19 10
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 19 11
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 20 11
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 11
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 20 12
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 20 12
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 21 12
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 22 12
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 22 12
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 23 12
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 23 12
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 24 12
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 25 12
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 25 12
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 25 13
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 25 13
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 25 14
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 26 14
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 14
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 26 15
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 26 15
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 27 15
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 28 15
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 28 15
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 29 15
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 29 15
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 30 15
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 31 15
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 31 15
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 31 16
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 31 16
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 31 17
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 32 17
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 32 17
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 32 18
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 32 18
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 33 18
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 34 18
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 34 18
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 35 18
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 35 18
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 36 18
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 37 18
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 37 18
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 37 19
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 37 19
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 37 20
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 38 20
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 38 20
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 38 21
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 38 21
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 39 21
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 40 21
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 40 21
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 41 21
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 41 21
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 42 21
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 43 21
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 43 21
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 43 22
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 43 22
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 43 23
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 44 23
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 44 23
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 44 24
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 44 24
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 45 24
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 46 24
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 46 24
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 47 24
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 47 24
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 48 24
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 49 24
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 49 24
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 49 25
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 49 25
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 49 26
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 50 26
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 50 26
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 50 27
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 50 27
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 51 27
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 52 27
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 52 27
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 53 27
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 53 27
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 54 27
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 55 27
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 55 27
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 55 28
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 55 28
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 55 29
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 56 29
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 56 29
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 56 30
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 56 30
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 57 30
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 58 30
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 58 30
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 59 30
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 59 30
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 60 30
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 61 30
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 61 30
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 61 31
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 61 31
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 61 32
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 62 32
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 62 32
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 62 33
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 62 33
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 63 33
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 64 33
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 64 33
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 65 33
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 65 33
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 66 33
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 67 33
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 67 33
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 67 34
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 67 34
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 67 35
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 68 35
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 68 35
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 68 36
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 68 36
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 69 36
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 70 36
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 70 36
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 71 36
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 71 36
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 72 36
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 73 36
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 73 36
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 73 37
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 73 37
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 73 38
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 74 38
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 74 38
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 74 39
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 74 39
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 75 39
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 76 39
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 76 39
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 77 39
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 77 39
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 78 39
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 79 39
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 79 39
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 79 40
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 79 40
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 79 41
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 80 41
# RT @DeeManser: @pritipatel Can we repatriate those Taliban supporters in our prisons on the return flights?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 80 41
# RT @other_mrs: May you step on Lego every fucking day. With a three pin plug chucked in for variety.
#
# And may you also face a sex starved…
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Negative
# 80 42
# @RepSteveChabot
# I didn't hear anything from you or your party when Dumpf released all the Taliban terrorists from… https://t.co/vAXTbhwrph
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 80 42
# RT @calxandr: NATO allies cannot organize an airlift for their own citizens.
#
# Vulnerable Afghans cannot get to the airport because of Talib…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.75)
# positive
# 81 42
# RT @gpsinghips: @assampolice has arrested 14 persons for social media posts regarding Taliban activities that have attracted provisions of…
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# positive
# 82 42
# RT @TajudenSoroush: Hashmat Ghani Ahmadzai, brother of fugitive president Ghani joined the Taliban. https://t.co/3dWCCOuNOP
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 82 42
# @ArJuNrAo2000 But it's Taliban 2.0
# This is good
#
# 😂😂
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# 83 42
# RT @Hilmi28: Ktka Israel menyerang Palestina, mrk blg itu cm konflik wilayah. Ktka etnis Rohingya dibantai Myanmar, mrka blg itu bkn urusan…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 83 42
# Right wing is offering free ticket to Afghanistan to all the true nationalist of Afghanistan residing in india and… https://t.co/AqQ7tfYoMe
# Sentiment(polarity=0.3452380952380952, subjectivity=0.6619047619047619)
# positive
# 84 42
# RT @RichardGrenell: The Trump team monitored the facts on the ground in real time - and constantly adjusted. And the Taliban believed they…
# Sentiment(polarity=0.1, subjectivity=0.31666666666666665)
# positive
# 85 42
# RT @trish_regan: We're relying on the TALIBAN to 'allow' Americans OUT of #Afghanistan.
#
# Let that sink in.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 85 42
# RT @ROKIBUZZAMAN2: Assam Police arrested 14 people from different districts for allegedly posting adverse and objectionable post supporting…
# Sentiment(polarity=-0.05, subjectivity=0.35)
# Negative
# 85 43
# RT @nikitheblogger: Die AfD wollen sie ausgrenzen.
# Mit den Taliban wollen sie reden.
# Muss man noch mehr über die etablierten Parteien in De…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# 85 43
# RT @arabnews: #Taliban co-founder Mullah Abdul Ghani Baradar arrives in #Kabul for talks with fellow members of the group and other politic…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# 85 44
# RT @amisyakhan: i'm so tired of explaining so many things about taliban to some Malaysians and their responses are always 'oh you got brain…
# Sentiment(polarity=0.04999999999999999, subjectivity=0.6)
# positive
# 86 44
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-285f4e6d2484> in <module>
#      31          csv_writer.writerow(info)
#      32          print(pos, neg)
# ---> 33          time.sleep(1)
#
# KeyboardInterrupt:
